# %%
st = 'Print only the words that start with s in this sentence'

# %%
st.split()
# Out:
# ['Print',
#  'only',
#  'the',
#  'words',
#  'that',
#  'start',
#  'with',
#  's',
#  'in',
#  'this',
#  'sentence']

# %%
for word in st.split():
    print(word)
# Out:
# Print
# only
# the
# words
# that
# start
# with
# s
# in
# this
# sentence

# %%
for word in st.split():
    if word[0] == 's':
        print(word)
# Out:
# start
# s
# sentence
